chroma-hnswlib, cachetools, bcrypt, backoff, asgiref, annotated-types, watchfiles, uvicorn, typing-inspect, types-requests, typer, starlette, pydantic-core, opentelemetry-proto, opentelemetry-api, marshmallow, googleapis-common-protos, google-auth, coloredlogs, build, requests-oauthlib, pydantic, posthog, opentelemetry-sdk, opentelemetry-instrumentation, opentelemetry-exporter-otlp-proto-common, onnxruntime, langchainhub, dataclasses-json, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, langsmith, kubernetes, fastapi, opentelemetry-instrumentation-fastapi, langchain-core, sentence-transformers, langchain-text-splitters, langchain-community, chromadb, langchain
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.16
#     Uninstalling urllib3-1.26.16:
#       Successfully uninstalled urllib3-1.26.16
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
#       Successfully uninstalled typing_extensions-4.7.1
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.2.2
#     Uninstalling tenacity-8.2.2:
#       Successfully uninstalled tenacity-8.2.2
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.0
#     Uninstalling packaging-23.0:
#       Successfully uninstalled packaging-23.0
#   Attempting uninstall: jsonpatch
#     Found existing installation: jsonpatch 1.32
#     Uninstalling jsonpatch-1.32:
#       Successfully uninstalled jsonpatch-1.32
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 3.2.0
#     Uninstalling bcrypt-3.2.0:
#       Successfully uninstalled bcrypt-3.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# tables 3.8.0 requires cython>=0.29.21, which is not installed.
# conda-repo-cli 1.0.41 requires requests_mock, which is not installed.
# botocore 1.29.76 requires urllib3<1.27,>=1.25.4, but you have urllib3 2.2.1 which is incompatible.
# conda-repo-cli 1.0.41 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.41 requires nbformat==5.4.0, but you have nbformat 5.7.0 which is incompatible.
# conda-repo-cli 1.0.41 requires requests==2.28.1, but you have requests 2.31.0 which is incompatible.
# Successfully installed annotated-types-0.6.0 asgiref-3.8.1 backoff-2.2.1 bcrypt-4.1.2 build-1.1.1 cachetools-5.3.3 chroma-hnswlib-0.7.3 chromadb-0.4.24 coloredlogs-15.0.1 dataclasses-json-0.6.4 deprecated-1.2.14 fastapi-0.110.0 flatbuffers-24.3.7 google-auth-2.29.0 googleapis-common-protos-1.63.0 grpcio-1.62.1 h11-0.14.0 httptools-0.6.1 humanfriendly-10.0 importlib-resources-6.4.0 jsonpatch-1.33 kubernetes-29.0.0 langchain-0.1.13 langchain-community-0.0.29 langchain-core-0.1.33 langchain-text-splitters-0.0.1 langchainhub-0.1.15 langsmith-0.1.31 marshmallow-3.21.1 mmh3-4.1.0 monotonic-1.6 oauthlib-3.2.2 onnxruntime-1.17.1 opentelemetry-api-1.23.0 opentelemetry-exporter-otlp-proto-common-1.23.0 opentelemetry-exporter-otlp-proto-grpc-1.23.0 opentelemetry-instrumentation-0.44b0 opentelemetry-instrumentation-asgi-0.44b0 opentelemetry-instrumentation-fastapi-0.44b0 opentelemetry-proto-1.23.0 opentelemetry-sdk-1.23.0 opentelemetry-semantic-conventions-0.44b0 opentelemetry-util-http-0.44b0 orjson-3.9.15 overrides-7.7.0 packaging-23.2 posthog-3.5.0 protobuf-4.25.3 pulsar-client-3.4.0 pydantic-2.6.4 pydantic-core-2.16.3 pypika-0.48.9 pyproject_hooks-1.0.0 python-dotenv-1.0.1 requests-oauthlib-2.0.0 rsa-4.9 sentence-transformers-2.6.0 starlette-0.36.3 tenacity-8.2.3 typer-0.10.0 types-requests-2.31.0.20240311 typing-extensions-4.10.0 typing-inspect-0.9.0 urllib3-2.2.1 uvicorn-0.29.0 uvloop-0.19.0 watchfiles-0.21.0 websockets-12.0

# %%
def make_rag_chain(model, retriever, rag_prompt = None):
    # We will use a prompt template from langchain hub.
    if not rag_prompt:
        rag_prompt = hub.pull("rlm/rag-prompt")

    # And we will use the LangChain RunnablePassthrough to add some custom processing into our chain.
    rag_chain = (
            {
                "context": RunnableLambda(get_question) | retriever | format_docs,
                "question": RunnablePassthrough()
            }
            | rag_prompt
            | model
    )

    return rag_chain


def get_question(input):
    if not input:
        return None
    elif isinstance(input,str):
        return input
    elif isinstance(input,dict) and 'question' in input:
        return input['question']
    elif isinstance(input,BaseMessage):
        return input.content
    else:
        raise Exception("string or dict with 'question' key expected as RAG chain input.")
        
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# %%
# !conda install -y pytorch==2.0.1 torchvision==0.15.2 torchaudio==2.0.2 pytorch-cuda=11.8 -c pytorch -c nvidia

import torch
# Out:
# Collecting package metadata (current_repodata.json): | DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/linux-64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/linux-64/current_repodata.json HTTP/1.1" 304 0
# done
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): | DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# / DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/linux-64/repodata.json HTTP/1.1" 304 0
# - DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/noarch/repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/linux-64/repodata.json HTTP/1.1" 304 0
# done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/fish/anaconda3
#
#   added / updated specs:
#     - pytorch-cuda=11.8
#     - pytorch==2.0.1
#     - torchaudio==2.0.2
#     - torchvision==0.15.2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2024.2.2           |  py311h06a4308_0         160 KB
#     conda-23.7.4               |  py311h06a4308_0         1.3 MB
#     conda-content-trust-0.2.0  |  py311h06a4308_0          61 KB
#     cuda-cudart-11.8.89        |                0         197 KB  nvidia
#     cuda-cupti-11.8.87         |                0        25.3 MB  nvidia
#     cuda-libraries-11.8.0      |                0           1 KB  nvidia
#     cuda-nvrtc-11.8.89         |                0        19.1 MB  nvidia
#     cuda-nvtx-11.8.86          |                0          57 KB  nvidia
#     cuda-runtime-11.8.0        |                0           1 KB  nvidia
#     ffmpeg-4.3                 |       hf484d3e_0         9.9 MB  pytorch
#     gnutls-3.6.15              |       he1e5248_0         1.0 MB
#     lame-3.100                 |       h7b6447c_0         323 KB
#     libcublas-11.11.3.6        |                0       364.0 MB  nvidia
#     libcufft-10.9.0.58         |                0       142.8 MB  nvidia
#     libcufile-1.9.0.20         |                0         1.0 MB  nvidia
#     libcurand-10.3.5.119       |                0        51.8 MB  nvidia
#     libcusolver-11.4.1.48      |                0        96.5 MB  nvidia
#     libcusparse-11.7.5.86      |                0       176.3 MB  nvidia
#     libiconv-1.16              |       h7f8727e_2         736 KB
#     libidn2-2.3.4              |       h5eee18b_0         146 KB
#     libnpp-11.8.0.86           |                0       147.8 MB  nvidia
#     libnvjpeg-11.9.0.86        |                0         2.4 MB  nvidia
#     libtasn1-4.19.0            |       h5eee18b_0          63 KB
#     libunistring-0.9.10        |       h27cfd23_0         536 KB
#     nettle-3.7.3               |       hbbd107a_1         809 KB
#     openh264-2.1.1             |       h4ff587b_0         711 KB
#     openssl-1.1.1w             |       h7f8727e_0         3.7 MB
#     pytorch-2.0.1              |py3.11_cuda11.8_cudnn8.7.0_0        1.41 GB  pytorch
#     pytorch-cuda-11.8          |       h7e8668a_5           3 KB  pytorch
#     pytorch-mutex-1.0          |             cuda           3 KB  pytorch
#     torchaudio-2.0.2           |      py311_cu118         7.6 MB  pytorch
#     torchtriton-2.0.0          |            py311        62.6 MB  pytorch
#     torchvision-0.15.2         |      py311_cu118         8.3 MB  pytorch
#     ------------------------------------------------------------
#                                            Total:        2.51 GB
#
# The following NEW packages will be INSTALLED:
#
#   cuda-cudart        nvidia/linux-64::cuda-cudart-11.8.89-0
#   cuda-cupti         nvidia/linux-64::cuda-cupti-11.8.87-0
#   cuda-libraries     nvidia/linux-64::cuda-libraries-11.8.0-0
#   cuda-nvrtc         nvidia/linux-64::cuda-nvrtc-11.8.89-0
#   cuda-nvtx          nvidia/linux-64::cuda-nvtx-11.8.86-0
#   cuda-runtime       nvidia/linux-64::cuda-runtime-11.8.0-0
#   ffmpeg             pytorch/linux-64::ffmpeg-4.3-hf484d3e_0
#   gnutls             pkgs/main/linux-64::gnutls-3.6.15-he1e5248_0
#   lame               pkgs/main/linux-64::lame-3.100-h7b6447c_0
#   libcublas          nvidia/linux-64::libcublas-11.11.3.6-0
#   libcufft           nvidia/linux-64::libcufft-10.9.0.58-0
#   libcufile          nvidia/linux-64::libcufile-1.9.0.20-0
#   libcurand          nvidia/linux-64::libcurand-10.3.5.119-0
#   libcusolver        nvidia/linux-64::libcusolver-11.4.1.48-0
#   libcusparse        nvidia/linux-64::libcusparse-11.7.5.86-0
#   libiconv           pkgs/main/linux-64::libiconv-1.16-h7f8727e_2
#   libidn2            pkgs/main/linux-64::libidn2-2.3.4-h5eee18b_0
#   libnpp             nvidia/linux-64::libnpp-11.8.0.86-0
#   libnvjpeg          nvidia/linux-64::libnvjpeg-11.9.0.86-0
#   libtasn1           pkgs/main/linux-64::libtasn1-4.19.0-h5eee18b_0
#   libunistring       pkgs/main/linux-64::libunistring-0.9.10-h27cfd23_0
#   nettle             pkgs/main/linux-64::nettle-3.7.3-hbbd107a_1
#   openh264           pkgs/main/linux-64::openh264-2.1.1-h4ff587b_0
#   pytorch-cuda       pytorch/linux-64::pytorch-cuda-11.8-h7e8668a_5
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cuda
#   torchaudio         pytorch/linux-64::torchaudio-2.0.2-py311_cu118
#   torchtriton        pytorch/linux-64::torchtriton-2.0.0-py311
#   torchvision        pytorch/linux-64::torchvision-0.15.2-py311_cu118
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.05.30-h06a4308_0 --> 2024.3.11-h06a4308_0
#   certifi                         2023.7.22-py311h06a4308_0 --> 2024.2.2-py311h06a4308_0
#   conda                              23.7.2-py311h06a4308_0 --> 23.7.4-py311h06a4308_0
#   conda-content-tru~ pkgs/main/noarch::conda-content-trust~ --> pkgs/main/linux-64::conda-content-trust-0.2.0-py311h06a4308_0
#   openssl                                 1.1.1u-h7f8727e_0 --> 1.1.1w-h7f8727e_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   pytorch            pkgs/main::pytorch-2.0.1-cpu_py311h6d~ --> pytorch::pytorch-2.0.1-py3.11_cuda11.8_cudnn8.7.0_0
#
#
#
# Downloading and Extracting Packages
# openh264-2.1.1       | 711 KB    |                                       |   0%
# conda-23.7.4         | 1.3 MB    |                                       |   0%
#
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# torchvision-0.15.2   | 8.3 MB    |                                       |   0% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
#
#
#
# libcufile-1.9.0.20   | 1.0 MB    |                                       |   0% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
#
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  |                                       |   0% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
#
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   |                                       |   0% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
#
#
#
#
#
#
# torchaudio-2.0.2     | 7.6 MB    |                                       |   0%
#
#
#
#
#
#
# libiconv-1.16        | 736 KB    |                                       |   0%
#
#
#
#
#
#
#
# gnutls-3.6.15        | 1.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# pytorch-cuda-11.8    | 3 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# pytorch-mutex-1.0    | 3 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.7.3         | 809 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2024.2.2     | 160 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-cudart-11.8.89  | 197 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-runtime-11.8.0  | 1 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-11.9.0.86  | 2.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtasn1-4.19.0      | 63 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lame-3.100           | 323 KB    |                                       |   0%
#  ... (more hidden) ...DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/linux-64/conda-23.7.4-py311h06a4308_0.conda HTTP/1.1" 200 1385246
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/linux-64/openh264-2.1.1-h4ff587b_0.conda HTTP/1.1" 200 727562
#
# openh264-2.1.1       | 711 KB    | ####9                                 |  14% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /nvidia/linux-64/libcufile-1.9.0.20-0.tar.bz2 HTTP/1.1" 200 1056943
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /nvidia/linux-64/libcublas-11.11.3.6-0.tar.bz2 HTTP/1.1" 200 381637889
#
#
#
# libcufile-1.9.0.20   | 1.0 MB    | 5                                     |   2%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  |                                       |   0% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /pytorch/linux-64/torchvision-0.15.2-py311_cu118.tar.bz2 HTTP/1.1" 200 8688971
#
#
# torchvision-0.15.2   | 8.3 MB    |                                       |   0% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
#
# openh264-2.1.1       | 711 KB    | ##################################### | 100%
#
#
# libcufile-1.9.0.20   | 1.0 MB    | #########7                            |  26%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  |                                       |   0%
#
# torchvision-0.15.2   | 8.3 MB    | ##7                                   |   7%
# conda-23.7.4         | 1.3 MB    | #############################7        |  80%
#
#
# libcufile-1.9.0.20   | 1.0 MB    | #################################2    |  90%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  |                                       |   0% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
#
#
# torchvision-0.15.2   | 8.3 MB    | ######3                               |  17% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
#
# conda-23.7.4         | 1.3 MB    | ##################################### | 100% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /nvidia/linux-64/libcurand-10.3.5.119-0.tar.bz2 HTTP/1.1" 200 54277644
#
#
#
# libcufile-1.9.0.20   | 1.0 MB    | ##################################### | 100%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   |                                       |   0%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | 1                                     |   0%
#
# torchvision-0.15.2   | 8.3 MB    | ########9                             |  24% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /pytorch/linux-64/torchaudio-2.0.2-py311_cu118.tar.bz2 HTTP/1.1" 200 7996457
#
#
#
#
#
#
# torchaudio-2.0.2     | 7.6 MB    |                                       |   0%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | 2                                     |   1%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | 7                                     |   2%
#
# torchvision-0.15.2   | 8.3 MB    | ###########5                          |  31% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/linux-64/libiconv-1.16-h7f8727e_2.conda HTTP/1.1" 200 753730
#
#
#
#
#
#
# torchaudio-2.0.2     | 7.6 MB    | 6                                     |   2%
#
#
#
#
#
#
# libiconv-1.16        | 736 KB    | 8                                     |   2%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | 3                                     |   1%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | #3                                    |   4%
#
# torchvision-0.15.2   | 8.3 MB    | ##############3                       |  39%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | 3                                     |   1%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | #8                                    |   5%
#
# torchvision-0.15.2   | 8.3 MB    | ################8                     |  46%
#
#
#
#
#
#
# libiconv-1.16        | 736 KB    | #######2                              |  20%
#
#
#
#
#
# torchaudio-2.0.2     | 7.6 MB    | ###4                                  |   9%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | 4                                     |   1%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ##3                                   |   6%
#
# torchvision-0.15.2   | 8.3 MB    | ###################3                  |  52%
#
#
#
#
#
#
# libiconv-1.16        | 736 KB    | ############                          |  33%
#
#
#
#
#
# torchaudio-2.0.2     | 7.6 MB    | #####3                                |  15%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | 5                                     |   1%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ##8                                   |   8%
#
#
#
#
#
#
# libiconv-1.16        | 736 KB    | ############################1         |  76%
#
# torchvision-0.15.2   | 8.3 MB    | #####################6                |  59%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | 5                                     |   2%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ###5                                  |  10%
#
#
#
#
#
# torchaudio-2.0.2     | 7.6 MB    | ########4                             |  23%
#
#
#
#
#
#
# libiconv-1.16        | 736 KB    | ####################################1 |  98%
#
# torchvision-0.15.2   | 8.3 MB    | #######################9              |  65%
#
#
#
#
#
#
# libiconv-1.16        | 736 KB    | ##################################### | 100%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | 6                                     |   2%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ####2                                 |  11%
#
#
#
#
#
# torchaudio-2.0.2     | 7.6 MB    | ###########6                          |  32% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/linux-64/gnutls-3.6.15-he1e5248_0.conda HTTP/1.1" 200 1054747
#
#
#
#
#
#
#
#
# gnutls-3.6.15        | 1.0 MB    | 5                                     |   2%
#
# torchvision-0.15.2   | 8.3 MB    | ##########################1           |  71%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ####8                                 |  13%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | 7                                     |   2%
#
#
#
#
#
#
#
# gnutls-3.6.15        | 1.0 MB    | ############6                         |  34%
#
#
#
#
#
# torchaudio-2.0.2     | 7.6 MB    | #############6                        |  37%
#
# torchvision-0.15.2   | 8.3 MB    | ############################2         |  76%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | #####4                                |  15%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | 7                                     |   2%
#
#
#
#
#
# torchaudio-2.0.2     | 7.6 MB    | ###############4                      |  42%
#
#
#
#
#
#
#
# gnutls-3.6.15        | 1.0 MB    | ####################1                 |  54%
#
# torchvision-0.15.2   | 8.3 MB    | ##############################3       |  82%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ######                                |  16%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | 8                                     |   2%
#
#
#
#
#
#
#
# gnutls-3.6.15        | 1.0 MB    | ###############################       |  84%
#
#
#
#
#
# torchaudio-2.0.2     | 7.6 MB    | #################2                    |  47%
#
# torchvision-0.15.2   | 8.3 MB    | ################################3     |  87%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ######5                               |  18%
# libcublas-11.11.3.6  | 364.0 MB  | 9                                     |   2%
#
#
#
#
#
#
#
# gnutls-3.6.15        | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
# torchaudio-2.0.2     | 7.6 MB    | ###################4                  |  52%
#
# torchvision-0.15.2   | 8.3 MB    | ##################################6   |  94%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | #######1                              |  19%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | 9                                     |   3%
#
#
#
#
#
# torchaudio-2.0.2     | 7.6 MB    | #####################2                |  57%
#
# torchvision-0.15.2   | 8.3 MB    | ####################################6 |  99% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /pytorch/linux-64/pytorch-cuda-11.8-h7e8668a_5.tar.bz2 HTTP/1.1" 200 3561
#
#
#
#
#
#
#
#
#
# pytorch-cuda-11.8    | 3 KB      | ##################################### | 100%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | #######7                              |  21%
#
#
#
#
#
#
#
#
# pytorch-cuda-11.8    | 3 KB      | ##################################### | 100%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | #                                     |   3%
#
#
#
#
#
# torchaudio-2.0.2     | 7.6 MB    | #######################1              |  63% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /pytorch/noarch/pytorch-mutex-1.0-cuda.tar.bz2 HTTP/1.1" 200 2906
#
#
#
#
#
#
#
#
#
#
#
# pytorch-mutex-1.0    | 3 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# pytorch-mutex-1.0    | 3 KB      | ##################################### | 100%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ########6                             |  23% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /pytorch/linux-64/ffmpeg-4.3-hf484d3e_0.tar.bz2 HTTP/1.1" 200 10426878
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    |                                       |   0%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | #1                                    |   3%
#
#
#
#
#
# torchaudio-2.0.2     | 7.6 MB    | #########################7            |  70%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ##1                                   |   6%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | #########4                            |  26%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | #1                                    |   3%
#
#
#
#
#
# torchaudio-2.0.2     | 7.6 MB    | ###########################8          |  75% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /nvidia/linux-64/libcusolver-11.4.1.48-0.tar.bz2 HTTP/1.1" 200 101143771
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ###7                                  |  10%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ##########1                           |  27%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | #2                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | 1                                     |   0%
#
#
#
#
#
# torchaudio-2.0.2     | 7.6 MB    | #############################8        |  81%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | #####                                 |  14%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ##########7                           |  29%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | #3                                    |   4%
#
#
#
#
#
# torchaudio-2.0.2     | 7.6 MB    | ###############################9      |  86%
#
# torchvision-0.15.2   | 8.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | 3                                     |   1%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ######6                               |  18%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ###########4                          |  31%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | #3                                    |   4%
#
#
#
#
#
# torchaudio-2.0.2     | 7.6 MB    | ##################################1   |  92%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ########1                             |  22%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | 4                                     |   1%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ############                          |  33%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | #4                                    |   4%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | #########7                            |  26%
#
#
#
#
#
# torchaudio-2.0.2     | 7.6 MB    | ####################################2 |  98%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | 6                                     |   2%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ############6                         |  34%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | #5                                    |   4%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ###########3                          |  31%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | #############2                        |  36%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | 7                                     |   2%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | #5                                    |   4% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /nvidia/linux-64/libcufft-10.9.0.58-0.tar.bz2 HTTP/1.1" 200 149741913
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  |                                       |   0%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ############9                         |  35%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | 9                                     |   2%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | #############9                        |  38%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | #6                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  |                                       |   0%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ##############4                       |  39%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ##############5                       |  39%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #                                     |   3%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | #6                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | 1                                     |   1%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ###############9                      |  43%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ###############1                      |  41%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #2                                    |   3%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | #7                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | 2                                     |   1%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | #################7                    |  48%
# torchaudio-2.0.2     | 7.6 MB    | ##################################### | 100%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ###############7                      |  42%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #3                                    |   4%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | #8                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | 3                                     |   1%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ###################3                  |  52%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ################3                     |  44%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #5                                    |   4%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | #8                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | 4                                     |   1%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ####################8                 |  56%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ################8                     |  46%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #7                                    |   5%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | #9                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | 5                                     |   2%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ######################4               |  61%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | #################4                    |  47%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #9                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | 6                                     |   2%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | #9                                    |   5%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ########################3             |  66%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ##################1                   |  49%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | 7                                     |   2%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ##########################2           |  71%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ##                                    |   6%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ##################7                   |  51%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ############################          |  76%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | 8                                     |   2%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ###################3                  |  52%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | #############################7        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | 9                                     |   3%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ###################9                  |  54%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ##6                                   |   7%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ###############################3      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | #                                     |   3%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ####################5                 |  56%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | #################################1    |  90%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ##8                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | #                                     |   3%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | #####################2                |  57%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ###                                   |   8%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ##################################8   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | #1                                    |   3%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | #####################8                |  59%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ##3                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ####################################8 |  99% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
#
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ######################5               |  61%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ##3                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ###4                                  |   9%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | #######################1              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | #2                                    |   3%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ###7                                  |  10%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ########################              |  65%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | #4                                    |   4% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/linux-64/nettle-3.7.3-hbbd107a_1.conda HTTP/1.1" 200 828846
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.7.3         | 809 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ###9                                  |  11%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | #5                                    |   4%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ########################6             |  67%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ####2                                 |  11%
# libcublas-11.11.3.6  | 364.0 MB  | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.7.3         | 809 KB    | #####8                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | #6                                    |   4%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | #########################3            |  69%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ####4                                 |  12%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.7.3         | 809 KB    | ##########################3           |  71%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | #7                                    |   5%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ##########################            |  70%
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ##################################### | 100%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ##6                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ####6                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.7.3         | 809 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.7.3         | 809 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | #8                                    |   5%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ##########################7           |  72% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /nvidia/linux-64/cuda-nvrtc-11.8.89-0.tar.bz2 HTTP/1.1" 200 20069921
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ####8                                 |  13%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ##6                                   |   7%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ###########################4          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | #9                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | 9                                     |   3%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ##7                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #####                                 |  14%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ############################1         |  76%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ##                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ##                                    |   6%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #####2                                |  14%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ##7                                   |   8%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ############################7         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ##                                    |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ##8                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #####4                                |  15%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ##8                                   |   8%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | #############################4        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ###6                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #####6                                |  15%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ##8                                   |   8%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ##############################        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ####6                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #####8                                |  16%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | #####4                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ##3                                   |   6%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ##############################7       |  83%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ######                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ######3                               |  17%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ##4                                   |   7%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ###############################3      |  85%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ######2                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | #######3                              |  20%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ##5                                   |   7%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ###############################8      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ########2                             |  22%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ######4                               |  17%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ##6                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | #########3                            |  25%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###1                                  |   8%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ######6                               |  18%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | #################################2    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ##7                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ##########2                           |  28%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###1                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ######8                               |  18%
# libcurand-10.3.5.119 | 51.8 MB   | #################################8    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ##7                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ###########2                          |  30%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###1                                  |   9%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ##################################4   |  93%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ######9                               |  19%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ##8                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ############2                         |  33%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ###################################1  |  95%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #######1                              |  19%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | #############1                        |  36%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ###################################8  |  97%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #######3                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ##############2                       |  38%
#
#
#
#
# libcurand-10.3.5.119 | 51.8 MB   | ####################################5 |  99%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #######4                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ###1                                  |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ###############1                      |  41%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #######6                              |  21%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ################7                     |  45% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /pytorch/linux-64/pytorch-2.0.1-py3.11_cuda11.8_cudnn8.7.0_0.tar.bz2 HTTP/1.1" 200 1513764970
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   |                                       |   0%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###4                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #######8                              |  21%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | #################8                    |  48%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ########                              |  22%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###5                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ###4                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   |                                       |   0%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###5                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ########1                             |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ##################8                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ###5                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   |                                       |   0%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###6                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ########3                             |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ###################8                  |  54%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ###6                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | 1                                     |   0%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###6                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ########5                             |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ####################8                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ########6                             |  24%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | #####################8                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ###8                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | 1                                     |   0%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ########8                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ######################7               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ###8                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | 1                                     |   0%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###8                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | #######################6              |  64%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #########                             |  24%
# libcufft-10.9.0.58   | 142.8 MB  | ###9                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | 2                                     |   1%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###8                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #########1                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ########################6             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ####                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | 2                                     |   1%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###9                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #########3                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ####1                                 |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | #########################5            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | 2                                     |   1%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ###9                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #########4                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ####2                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ##########################5           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | 2                                     |   1%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ####                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ###########################4          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ####3                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #########6                            |  26%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ####                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ############################3         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ####4                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #########7                            |  26%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ####1                                 |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | #############################2        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ####5                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | #########9                            |  27%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ####1                                 |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ##############################1       |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ####6                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ##########                            |  27%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ####2                                 |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ##############################9       |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ####7                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ##########1                           |  27%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ####2                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ###############################8      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ####8                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ##########3                           |  28%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ####3                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ################################7     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | ####9                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ##########4                           |  28%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ####4                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | #################################6    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | #####                                 |  14%
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | ##########5                           |  29%
#
#
#
# libcublas-11.11.3.6  | 364.0 MB  | ####4                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.8.89   | 19.1 MB   | ##################################5   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ############################9         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################         |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################1        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################1        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################1        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################2        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################2        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################3        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################3        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################3        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################4        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################4        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################4        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################4        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################5        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################5        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################5        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################6        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################6        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################7        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################7        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################7        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################8        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################8        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################8        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################9        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################9        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #############################9        |  81%
# pytorch-2.0.1        | 1.41 GB   | ##############################        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################1       |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################1       |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################1       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################2       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################2       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################3       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################3       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################3       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################4       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################4       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################5       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################5       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################6       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################7       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################7       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################8       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################8       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################9       |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##############################9       |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###############################       |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###############################1      |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###############################1      |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###############################2      |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###############################3      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###############################3      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###############################4      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###############################5      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###############################5      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###############################6      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###############################7      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###############################7      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###############################8      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###############################8      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###############################9      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ################################      |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ################################      |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ################################1     |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ################################1     |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ################################2     |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ################################3     |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ################################3     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ################################4     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ################################6     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ################################7     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ################################7     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ################################8     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ################################9     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ################################9     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #################################     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #################################1    |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #################################1    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #################################2    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #################################3    |  90%
# pytorch-2.0.1        | 1.41 GB   | #################################3    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #################################4    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #################################5    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #################################5    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #################################6    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #################################6    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #################################7    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #################################8    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #################################8    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | #################################9    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##################################    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##################################    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##################################1   |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##################################2   |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##################################2   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##################################3   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##################################3   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##################################4   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##################################5   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##################################5   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##################################6   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##################################7   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##################################7   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##################################8   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##################################9   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##################################9   |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###################################   |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###################################1  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###################################1  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###################################2  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###################################3  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###################################3  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###################################4  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###################################5  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###################################5  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###################################6  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###################################6  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###################################7  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###################################8  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###################################8  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ###################################9  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ####################################  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ####################################  |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ####################################1 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ####################################2 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ####################################2 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ####################################3 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ####################################4 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ####################################4 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ####################################5 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ####################################6 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ####################################6 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ####################################7 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ####################################8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ####################################8 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ####################################9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.0.1        | 1.41 GB   | ##################################### | 100%
# pytorch-2.0.1        | 1.41 GB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import pandas as pd
import os
import torch
torch.cuda.is_available()

from huggingface_hub import login
from transformers import pipeline
from transformers import AutoModelForCausalLM, AutoTokenizer

from langchain_core.documents.base import Document
from langchain_community.document_loaders import TextLoader
from langchain_community.embeddings.sentence_transformer import (
    SentenceTransformerEmbeddings,
)
from langchain_community.vectorstores import Chroma
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.llms import HuggingFaceEndpoint
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain



# Set up the Hugging Face Hub API token
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"
login()
cache_dir = "./models"
os.environ['HF_HOME'] = './cache/'

if torch.cuda.is_available():
    model_id = "meta-llama/Llama-2-7b-chat-hf"
    model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto", cache_dir=cache_dir)
    model.cuda()
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    tokenizer.use_default_system_prompt = False

pipe = pipeline(
     "text-generation", 
     model=model, 
     tokenizer=tokenizer,
     return_tensors='pt',
     max_length=512,
     max_new_tokens=512,
     model_kwargs={"torch_dtype": torch.bfloat16},
     device="cuda"
    )

llm = HuggingFacePipeline(
 pipeline=pipe,
 model_kwargs={"temperature": 0.7, "max_length": 512},
)

df = pd.read_excel("bot2/optymize.xlsx")
data_list = df.values.ravel().tolist()
document_list = []

for content in data_list:
    document = Document(content=content, page_content=content)
    document_list.append(document)
text_splitter = CharacterTextSplitter(chunk_size=500, chunk_overlap=0)
docs = text_splitter.split_documents(document_list)
embedding_function = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
db = Chroma.from_documents(docs, embedding_function)
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]

# %%
from langchain import hub
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough, RunnableLambda
from langchain.chains import RetrievalQA

retriever = db.as_retriever(search_type="mmr", search_kwargs={'k': 4, 'fetch_k': 20})
prompt = hub.pull("rlm/rag-prompt")
rag_chain = make_rag_chain(model, retriever, rag_prompt = prompt)

# %%
questions = [
        "what is Optymize?",
        "how can i deposite coin on Optymize?",
        "what is Optymize's twitter?",
        "what is gOPZ tokens?",
        "what is Optymize tokenomics?",
        "what is Optymize details tokenomics?",
        "Optymize Vault Model – How does it works?, detail explaination",
        "Optymize Vault Model – How does it works?"
        ]
for q in questions:
    print("\n--- QUESTION: ", q)
    print("* Ans:\n", rag_chain.invoke(q))
# Out:
# --- QUESTION:  what is Optymize?
# * Ans:
#   Optymize allows users to stake their tokens to earn return in the form of OPZ (Optimizable Z tokens) plus an opportunity to earn common ownership rewards via gOPZ. This means the number of Optymize Vaults that can be created is limited by capital and user stake rates to ensure the network remains sustainable.
#
# --- QUESTION:  how can i deposite coin on Optymize?
# * Ans:
#   Deposit by staking your tokens into the Optymize Vault, bearing the risk of a Security Incident. Each token can be deposited for the purpose of earning both Opz revenues and tiered APY rewards related to liquidity pool activities on the exchange.
#
# --- QUESTION:  what is Optymize's twitter?
# * Ans:
#   Optymize's Twitter handle is @Optymize_xyz.
#
# --- QUESTION:  what is gOPZ tokens?
# * Ans:
#   The gOPZ tokens can be earned by staking OPZ tokens with us. The length of lockup depends on the user’s preference, but it generally starts from 60 days and can go as far as 24 months.
#
# --- QUESTION:  what is Optymize tokenomics?
# * Ans:
#   Optymize tokenomics involves selecting tokens to be pooled together based on various factors like TVL, risk, audit scores, market demand, and community feedback. The tokens can be staked to earn APY, and from there investors can indirectly contribute to the profitability of the protocol.
#
# --- QUESTION:  what is Optymize details tokenomics?
# * Ans:
#   Optymize details tokenomics are the factors that contribute to the creation and management of stable coins within the Optymize Vault by selectively pooling tokens based on several factors including TVL, risk ranking, audit scores, market demand and community feedback.
#
# --- QUESTION:  Optymize Vault Model – How does it works?, detail explaination
# * Ans:
#   Optymize Vault Model creates vaults for the staking of tokens to earn yield and mitigate Security Incident risk. It shares losses proportionally among all depositors when a Security Incident happens, and uses an intelligent algorithm to manage risks while sharing token prices proportionally among all depositors.
#
# --- QUESTION:  Optymize Vault Model – How does it works?
# * Ans:
#   The Optymize Vault model utilizes a risk-sharing system among all the depositors by pooling their tokens and sharing the losses proportionally during Security Incidents.

# %%
question = """The Optymize Protocol is a first-of-its-kind multi-blockchain solution that combines both yield enhancement and risk mitigation for crypto assets.
Explain more on the keywords here"""

template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate.from_template(template)

llm_chain = LLMChain(prompt=prompt, llm=llm)
llm_chain.invoke(question)
# Out:
# {'question': 'The Optymize Protocol is a first-of-its-kind multi-blockchain solution that combines both yield enhancement and risk mitigation for crypto assets.\nExplain more on the keywords here',
#  'text': '\n\n- **Multi-blockchain**: It highlights that the protocol operates across multiple blockchains, opening up opportunities for broader reach and cross-asset market participation.\n\n- **Yield Enhancement**: This means finding and securing opportunities to earn additional income from crypto assets, often through staking or lending processes.\n\n- **Risk Mitigation**: It suggests strategies and measures taken to minimize potential financial losses and protect capital against market volatility.\n\n- ** crypto assets**: This refers to various cryptocurrencies and other crypto-based assets, such as NFTs or DeFi protocols.'}

# %%
qs = [{'question': question}]
res = llm_chain.generate(qs)
print(res.generations)
# Out:
# [[Generation(text='\n\n- **Multi-blockchain**: It highlights that the protocol operates across multiple blockchains, opening up opportunities for broader reach and cross-asset market participation.\n\n- **Yield Enhancement**: This means finding and securing opportunities to earn additional income from crypto assets, often through staking or lending processes.\n\n- **Risk Mitigation**: It suggests strategies and measures taken to minimize potential financial losses and protect capital against market volatility.\n\n- ** crypto assets**: This refers to various cryptocurrencies and other crypto-based assets, such as NFTs or DeFi protocols.')]]
